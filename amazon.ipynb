# %%
# importing the libraries

import numpy as np # numerical python : helps you work with numbers in the dataet
import pandas as pd # reading the dataset + manipulation + wrangling
import matplotlib.pyplot as plt # basic math graphs : bar chart, line chart, pie chart, donut chart,
import seaborn as sns # statistical data visualization library :
# box whisker plots, histograms, skewness + bias , violin plots


# warnings module
import warnings
warnings.filterwarnings('ignore')

# mount the google drive (only for collab notebooks)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/Amazon_Orders.xlsx')
df.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 1     Paul Henriot         4551
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545

# %%
df.tail()
# last 5 records
# Out:
#       Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 2495   1680806         1304            Italy 2023-06-23 00:29:00          App
# 2496   1681214          291            India 2023-05-15 01:00:00      Website
# 2497   1681720           71            India 2023-04-06 00:24:00        Other
# 2498   1682186         1537              USA 2023-07-31 00:50:00          App
# 2499   1682358          567        Australia 2023-03-27 23:19:00      Website
#
#                 Sales POC  Order Value
# 2495       Janine Labrune         3072
# 2496          Jan Klaeboe         8168
# 2497  Michael Donnermeyer         1552
# 2498          Steve Frick         9912
# 2499        Helen Bennett         4540

# %%
# print the first 10 records in the dataset
df.head(10)
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
# 5      4111         1367            Italy 2023-03-08 22:52:00          App
# 6      4801          945           France 2023-02-18 00:23:00        Other
# 7      5719          218           France 2023-11-23 01:10:00      Website
# 8      5846          264              USA 2023-12-23 01:20:00      Website
# 9      7615          566              USA 2023-11-03 23:46:00     Whatsapp
#
#            Sales POC  Order Value
# 0            Kwai Yu          412
# 1       Paul Henriot         4551
# 2    Daniel Da Cunha         3960
# 3        Julie Young         8397
# 4        Julie Brown         5545
# 5        Juri Hirano         7800
# 6      Martine Rance         4674
# 7      Veysel Oeztan         5954
# 8       Julie Murphy         9887
# 9  Dominique Perrier         8303

# %%
df . shape
# Out:
# (2500, 7)

# %%
# in order to know, how many rows and columns are there in my dataset

print("Dimensions of my dataset are:", df.shape)
print("-" * 40)
print("Number of rows: ", df.shape[0])
print("Number of Columns: ", df.shape[1])

# output : (rows,columns)
# Out:
# Dimensions of my dataset are: (2500, 7)
# ----------------------------------------
# Number of rows:  2500
# Number of Columns:  7

# %%
# how to print all the  columns in the dataset

print("Columns in the dataset are: \n",df.columns)
# Out:
# Columns in the dataset are:
#  Index(['Order ID', 'Customer ID', 'Customer Country', 'Order Datetime',
#        'Order Source', 'Sales POC', 'Order Value'],
#       dtype='object')

# %%
# To get information about the dataset
print("Dataset info:\n")
df.info()
# Out:
# Dataset info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          2500 non-null   int64
#  1   Customer ID       2500 non-null   int64
#  2   Customer Country  2493 non-null   object
#  3   Order Datetime    2500 non-null   datetime64[ns]
#  4   Order Source      2483 non-null   object
#  5   Sales POC         2500 non-null   object
#  6   Order Value       2500 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 136.8+ KB

# %%
# to check the number of missing values in the dataset
df.isnull().sum()
# Out:
# Order ID             0
# Customer ID          0
# Customer Country     7
# Order Datetime       0
# Order Source        17
# Sales POC            0
# Order Value          0
# dtype: int64

# %%
# missing values representation in percentage terms
# formulae = total missing values / number of rows * 100

percentage_missing_values = (df.isnull().sum())/ len(df) * 100

print(percentage_missing_values)
# Out:
# Order ID            0.00
# Customer ID         0.00
# Customer Country    0.28
# Order Datetime      0.00
# Order Source        0.68
# Sales POC           0.00
# Order Value         0.00
# dtype: float64

# %%
# how to access the columns in the dataset

# dot notation
# bracket notation

# %%
# example : bracket notation
# df['column_name']

df['Customer Country']
# Out:
# 0             USA
# 1           India
# 2             USA
# 3             USA
# 4             USA
#           ...
# 2495        Italy
# 2496        India
# 2497        India
# 2498          USA
# 2499    Australia
# Name: Customer Country, Length: 2500, dtype: object

# %%
# subset : sales data
# when you want to pass or access multiple columns
# pass them inside a list

# We end up creating a seperate subset of sales data
# subset : small portion / sample from the entire dataset

sales_subset = df[['Order ID' , 'Customer ID' , 'Sales POC' ]]

sales_subset.head()


# sales_subset.head()
# Out:
#    Order ID  Customer ID        Sales POC
# 0      1597          856          Kwai Yu
# 1      2011          525     Paul Henriot
# 2      2822         1614  Daniel Da Cunha
# 3      2889          743      Julie Young
# 4      3971           20      Julie Brown

# %%
print("Columns in the dataset are: \n",df.columns)
# Out:
# Columns in the dataset are:
#  Index(['Order ID', 'Customer ID', 'Customer Country', 'Order Datetime',
#        'Order Source', 'Sales POC', 'Order Value'],
#       dtype='object')

# %%
sales_subset.shape
# Out:
# (2500, 3)

# %%
df.columns
# Out:
# Index(['Order ID', 'Customer ID', 'Customer Country', 'Order Datetime',
#        'Order Source', 'Sales POC', 'Order Value'],
#       dtype='object')

# %%
# data manipulation

#  Descriptive Stats : only for numerical columns

print("Descriptive Statistics : \n")

df.describe()

# Min to max : 5 point summary
# important in building IQR : Inter Quartile Range : Outlier study
# Out:
# Descriptive Statistics :
#            Order ID  Customer ID              Order Datetime  Order Value
# count  2.500000e+03  2500.000000                        2500  2500.000000
# mean   8.418021e+05  1004.997200  2023-07-01 05:35:16.656000  4910.356000
# min    1.597000e+03     1.000000         2023-01-01 00:44:00    10.000000
# 25%    4.427852e+05   496.250000         2023-03-30 17:52:45  2364.000000
# 50%    8.343515e+05  1006.500000         2023-06-30 12:41:30  4737.000000
# 75%    1.254761e+06  1511.000000         2023-10-03 00:15:15  7439.250000
# max    1.682358e+06  1998.000000         2023-12-31 23:34:00  9994.000000
# std    4.829208e+05   579.479753                         NaN  2904.610003

# %%
df.describe().T
# Out:
#                  count                        mean                  min  \
# Order ID        2500.0                  841802.148               1597.0
# Customer ID     2500.0                   1004.9972                  1.0
# Order Datetime    2500  2023-07-01 05:35:16.656000  2023-01-01 00:44:00
# Order Value     2500.0                    4910.356                 10.0
#
#                                 25%                  50%                  75%  \
# Order ID                  442785.25             834351.5            1254761.0
# Customer ID                  496.25               1006.5               1511.0
# Order Datetime  2023-03-30 17:52:45  2023-06-30 12:41:30  2023-10-03 00:15:15
# Order Value                  2364.0               4737.0              7439.25
#
#                                 max            std
# Order ID                  1682358.0  482920.821929
# Customer ID                  1998.0     579.479753
# Order Datetime  2023-12-31 23:34:00            NaN
# Order Value                  9994.0    2904.610003

# %%
df.describe(include = 'all')
# Out:
#             Order ID  Customer ID Customer Country  \
# count   2.500000e+03  2500.000000             2493
# unique           NaN          NaN               14
# top              NaN          NaN              USA
# freq             NaN          NaN              885
# mean    8.418021e+05  1004.997200              NaN
# min     1.597000e+03     1.000000              NaN
# 25%     4.427852e+05   496.250000              NaN
# 50%     8.343515e+05  1006.500000              NaN
# 75%     1.254761e+06  1511.000000              NaN
# max     1.682358e+06  1998.000000              NaN
# std     4.829208e+05   579.479753              NaN
#
#                     Order Datetime Order Source     Sales POC  Order Value
# count                         2500         2483          2500  2500.000000
# unique                         NaN            4            92          NaN
# top                            NaN      Website  Diego Freyre          NaN
# freq                           NaN          637           232          NaN
# mean    2023-07-01 05:35:16.656000          NaN           NaN  4910.356000
# min            2023-01-01 00:44:00          NaN           NaN    10.000000
# 25%            2023-03-30 17:52:45          NaN           NaN  2364.000000
# 50%            2023-06-30 12:41:30          NaN           NaN  4737.000000
# 75%            2023-10-03 00:15:15          NaN           NaN  7439.250000
# max            2023-12-31 23:34:00          NaN           NaN  9994.000000
# std                            NaN          NaN           NaN  2904.610003

# %%
print("Unique values......\n")

df['Customer Country'].unique()
# Out:
# Unique values......
# array(['USA', 'India', 'Italy', 'France', 'Spain', 'Singapore',
#        'Australia', 'Germany', 'Norway', 'Austria', 'Finland',
#        'Switzerland', 'Ireland', 'Denmark', nan], dtype=object)

# %%
df['Customer Country'].nunique() # nunique : number of unique categories
# Out:
# 14

# %%
# value counts : tells you with respect to a category how many records are there
# prefer for object or categorical columns only

df['Customer Country'].value_counts()
# Out:
# Customer Country
# USA            885
# France         323
# India          281
# Spain          268
# Australia      198
# Italy          112
# Singapore       97
# Finland         66
# Denmark         66
# Germany         58
# Austria         43
# Norway          40
# Switzerland     36
# Ireland         20
# Name: count, dtype: int64

# %%
df['Order Value'].value_counts(normalize=True) # tells you percentage distribution
# Out:
# Order Value
# 6840    0.0012
# 936     0.0012
# 3114    0.0012
# 9670    0.0012
# 1650    0.0012
#          ...
# 4645    0.0004
# 148     0.0004
# 8164    0.0004
# 1581    0.0004
# 7774    0.0004
# Name: proportion, Length: 2213, dtype: float64

# %%
counts = df['Customer ID'].value_counts()
percentages = df['Customer ID'].value_counts(normalize=True)

print("Counts:\n", counts)
print("-" * 50)
print("\nPercentages:\n", percentages)
print("-" * 50)
result = pd.DataFrame({'Counts': counts, 'Percentages': percentages})
print("Combined results are:", result)
# Out:
# Counts:
#  Customer ID
# 1948    7
# 1367    6
# 214     6
# 1510    5
# 899     5
#        ..
# 1016    1
# 1681    1
# 1414    1
# 566     1
# 743     1
# Name: count, Length: 1453, dtype: int64
# --------------------------------------------------
#
# Percentages:
#  Customer ID
# 1948    0.0028
# 1367    0.0024
# 214     0.0024
# 1510    0.0020
# 899     0.0020
#          ...
# 1016    0.0004
# 1681    0.0004
# 1414    0.0004
# 566     0.0004
# 743     0.0004
# Name: proportion, Length: 1453, dtype: float64
# --------------------------------------------------
# Combined results are:              Counts  Percentages
# Customer ID
# 1948              7       0.0028
# 1367              6       0.0024
# 214               6       0.0024
# 1510              5       0.0020
# 899               5       0.0020
# ...             ...          ...
# 1016              1       0.0004
# 1681              1       0.0004
# 1414              1       0.0004
# 566               1       0.0004
# 743               1       0.0004
#
# [1453 rows x 2 columns]

# %%
# to create 2 seperate subsets for numerical and categorical dataset
numerical_df = df.select_dtypes(include = 'number')
numerical_df.head()
# Out:
#    Order ID  Customer ID  Order Value
# 0      1597          856          412
# 1      2011          525         4551
# 2      2822         1614         3960
# 3      2889          743         8397
# 4      3971           20         5545

# %%
numerical_df_x = df.select_dtypes(include = ['int64','float64'])
numerical_df_x.head()
# Out:
#    Order ID  Customer ID  Order Value
# 0      1597          856          412
# 1      2011          525         4551
# 2      2822         1614         3960
# 3      2889          743         8397
# 4      3971           20         5545

# %%
categorical_df = df.select_dtypes(include = 'object')
categorical_df.head()
# Out:
#   Customer Country Order Source        Sales POC
# 0              USA        Other          Kwai Yu
# 1            India     Whatsapp     Paul Henriot
# 2              USA     Whatsapp  Daniel Da Cunha
# 3              USA     Whatsapp      Julie Young
# 4              USA      Website      Julie Brown

# %%
# exporting the dataset to a csv or excel file
numerical_df_x.to_csv('numerical_dataset.csv')
# numerical_df_x.to_excel('numerical_dataset.xlsx')
numerical_df_x.to_excel('numerical_dataset.xlsx', index=False)

# %%
df.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 1     Paul Henriot         4551
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545

# %%
# create a copy of df

df_copy = df.copy()

df_copy.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 1     Paul Henriot         4551
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545

# %%
df_copy.drop(columns=['Order Datetime', 'Sales POC', 'Order Value'],
                           axis=1,
             inplace=True) # axis = 1 means performing an operation on a column
                           # operation means dropping a column or columns or renaming columns

# axis = 0 means performing row wise operation

# %%
# dataframe after dropping columns
df_copy.head()
# Out:
#    Order ID  Customer ID Customer Country Order Source
# 0      1597          856              USA        Other
# 1      2011          525            India     Whatsapp
# 2      2822         1614              USA     Whatsapp
# 3      2889          743              USA     Whatsapp
# 4      3971           20              USA      Website

# %%
# original dataframe
df.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 1     Paul Henriot         4551
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545

# %%
df_copy.columns
# Out:
# Index(['Order ID', 'Customer ID', 'Customer Country', 'Order Source'], dtype='object')

# %%
# rename function
# inside rename function you pass a dictionary
# {"Old column name" : "New columm name"}

df_copy.rename({"Customer Country" : "customer_cu",
                "Customer Gender" : "customer_gender",
                "Customer Category" : "customer_category"}, axis=1 , inplace=True)

# %%
df_copy.head()
# Out:
#    Order ID  Customer ID customer_cu Order Source
# 0      1597          856         USA        Other
# 1      2011          525       India     Whatsapp
# 2      2822         1614         USA     Whatsapp
# 3      2889          743         USA     Whatsapp
# 4      3971           20         USA      Website

# %%
df.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 1     Paul Henriot         4551
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545

# %%
df['Customer ID'].value_counts().sort_values()
# sorted in ascending manner
# Out:
# Customer ID
# 566     1
# 1414    1
# 1681    1
# 1016    1
# 1581    1
#        ..
# 1510    5
# 1512    5
# 1367    6
# 214     6
# 1948    7
# Name: count, Length: 1453, dtype: int64

# %%
df['Customer ID'].value_counts().sort_index()
# this is how you sort the index values
# Out:
# Customer ID
# 1       1
# 3       1
# 5       1
# 7       1
# 9       2
#        ..
# 1992    1
# 1993    2
# 1994    1
# 1997    2
# 1998    2
# Name: count, Length: 1453, dtype: int64

# %%
df['Customer Country'].value_counts().sort_index().plot.bar(color='red') #plot.bar() means bar plot
# vertical bar plot
# Out:
# <Axes: xlabel='Customer Country'>

# %%
df['Customer Country'].value_counts().sort_index().plot.barh(color='green')
# Out:
# <Axes: ylabel='Customer Country'>

# %%
# how to export the bar plot image to png
ax = df['Customer Country'].value_counts().sort_index().plot.bar(color='red')

import matplotlib.pyplot as plt

plt.title("Genre Bar plot")
plt.xlabel("Genre")
plt.ylabel("Count")
#plt.xticks(rotation=45)
plt.savefig("genre_bar_plot4.png",bbox_inches='tight')

plt.show()

# %%
# loc and iloc method
# filtering mechanism : condition ke basis pe
# df.loc[]
# df.iloc[]
# 99% overlap
# df.loc[rows,columns]

# %%
df.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 1     Paul Henriot         4551
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545

# %%
sales_df = df[['Order ID' , 'Customer ID' , 'Sales POC','Order Value']]

sales_df.head()
# Out:
#    Order ID  Customer ID        Sales POC  Order Value
# 0      1597          856          Kwai Yu          412
# 1      2011          525     Paul Henriot         4551
# 2      2822         1614  Daniel Da Cunha         3960
# 3      2889          743      Julie Young         8397
# 4      3971           20      Julie Brown         5545

# %%
# df.loc[]
sales_df = df.loc[0:99,['Order ID' , 'Customer ID' , 'Sales POC','Order Value']]

# %%
sales_df.shape
# Out:
# (100, 4)

# %%
sales_df
# Out:
#     Order ID  Customer ID        Sales POC  Order Value
# 0       1597          856          Kwai Yu          412
# 1       2011          525     Paul Henriot         4551
# 2       2822         1614  Daniel Da Cunha         3960
# 3       2889          743      Julie Young         8397
# 4       3971           20      Julie Brown         5545
# ..       ...          ...              ...          ...
# 95     61005          480  Marta Hernandez         7727
# 96     61504          260  Matti Karttunen         7129
# 97     61520         1870      Steve Frick         3077
# 98     63153          765         Kyung Yu         5427
# 99     64461         1755          Kwai Yu         7725
#
# [100 rows x 4 columns]

# %%
# df.iloc[]
# 0:500
# .iloc : startting index to ending index  - 1
sales_df = df.iloc[0:100,2:5] #starting position to n-1

# %%
sales_df.shape
# Out:
# (100, 3)

# %%
sales_df
# Out:
#    Customer Country      Order Datetime Order Source
# 0               USA 2023-12-15 00:50:00        Other
# 1             India 2023-04-29 23:40:00     Whatsapp
# 2               USA 2023-12-30 00:21:00     Whatsapp
# 3               USA 2023-11-28 00:31:00     Whatsapp
# 4               USA 2023-10-26 23:11:00      Website
# ..              ...                 ...          ...
# 95          Finland 2023-01-02 00:46:00        Other
# 96              USA 2023-12-26 00:32:00          App
# 97              USA 2023-06-22 23:37:00     Whatsapp
# 98           Norway 2023-03-28 23:27:00     Whatsapp
# 99            Spain 2023-03-21 23:38:00     Whatsapp
#
# [100 rows x 3 columns]

# %%
# want to fetch out the value at 100th index position in NA_Sales column
df.loc[100, "Customer Country"]
# Out:
# 'Australia'

# %%
# Assign the string value 'Spain' to the cell, enclosed in quotes
df.loc[100, "Customer Country"] = 'Spain'

# %%
df.loc[100, "Customer Country"]
# Out:
# 'Spain'

# %%
df.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 1      2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 1     Paul Henriot         4551
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545

# %%
# Technique 1 : Subset
india = df['Customer Country'] == "India"

# %%
india
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 2495    False
# 2496     True
# 2497     True
# 2498    False
# 2499    False
# Name: Customer Country, Length: 2500, dtype: bool

# %%
India = df.loc[india]
India
# Out:
#       Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 1         2011          525            India 2023-04-29 23:40:00     Whatsapp
# 12        9839          223            India 2023-06-05 01:05:00        Other
# 13       10101          276            India 2023-11-27 22:29:00          App
# 15       10508         1016            India 2023-08-24 23:13:00     Whatsapp
# 28       16847          406            India 2023-11-08 00:17:00        Other
# ...        ...          ...              ...                 ...          ...
# 2484   1675193          552            India 2023-11-12 23:47:00     Whatsapp
# 2486   1675528          360            India 2023-07-30 00:12:00     Whatsapp
# 2491   1677717          376            India 2023-06-21 23:56:00        Other
# 2496   1681214          291            India 2023-05-15 01:00:00      Website
# 2497   1681720           71            India 2023-04-06 00:24:00        Other
#
#                 Sales POC  Order Value
# 1            Paul Henriot         4551
# 12          William Brown         7215
# 13             Julie King         6947
# 15        Marta Hernandez         4247
# 28          Mart¡n Sommer         1802
# ...                   ...          ...
# 2484       Peter Ferguson         2913
# 2486           Wing C Tam         3204
# 2491       Peter Ferguson         8542
# 2496          Jan Klaeboe         8168
# 2497  Michael Donnermeyer         1552
#
# [281 rows x 7 columns]

# %%
India.shape
# Out:
# (281, 7)

# %%
# Technique 2 : Subset

ps3 = df.loc[df['Customer Country'] == "USA"]

ps3.head()
# Out:
#    Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0      1597          856              USA 2023-12-15 00:50:00        Other
# 2      2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3      2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4      3971           20              USA 2023-10-26 23:11:00      Website
# 8      5846          264              USA 2023-12-23 01:20:00      Website
#
#          Sales POC  Order Value
# 0          Kwai Yu          412
# 2  Daniel Da Cunha         3960
# 3      Julie Young         8397
# 4      Julie Brown         5545
# 8     Julie Murphy         9887

# %%
# Filter out those records, where Japan Sales are greater than Europe Sales

Orderid_Greaterthan_Salestg = df.loc[df['Order ID'] > df['Order Value']]

Orderid_Greaterthan_Salestg.head()
# Out:
#     Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 0       1597          856              USA 2023-12-15 00:50:00        Other
# 6       4801          945           France 2023-02-18 00:23:00        Other
# 11      9339         1681            Spain 2023-12-18 00:39:00          App
# 12      9839          223            India 2023-06-05 01:05:00        Other
# 13     10101          276            India 2023-11-27 22:29:00          App
#
#         Sales POC  Order Value
# 0         Kwai Yu          412
# 6   Martine Rance         4674
# 11  Michael Frick         2782
# 12  William Brown         7215
# 13     Julie King         6947

# %%
# how many such records do we have ?

Orderid_Greaterthan_Salestg.shape[0]
# Out:
# 2491

# %%
Orderid_Greaterthan_Salestg = df.loc[df['Order ID'] > df['Order Value'] , ['Order ID' , 'Customer ID' , 'Sales POC','Customer Country']]

Orderid_Greaterthan_Salestg.head()
# Out:
#     Order ID  Customer ID      Sales POC Customer Country
# 0       1597          856        Kwai Yu              USA
# 6       4801          945  Martine Rance           France
# 11      9339         1681  Michael Frick            Spain
# 12      9839          223  William Brown            India
# 13     10101          276     Julie King            India

# %%
Orderid_Greaterthan_Salestg.to_csv('Orderid_Greaterthan_Salestg.csv')

# %%
df.loc[(df['Customer Country'] == "India") & (df['Sales POC'] == "Julie King")]
# Out:
#       Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 13       10101          276            India 2023-11-27 22:29:00          App
# 211     146917          183            India 2023-02-24 01:46:00        Other
# 1697   1129422          327            India 2023-10-21 01:26:00      Website
# 1849   1239461          245            India 2023-09-14 01:17:00      Website
#
#        Sales POC  Order Value
# 13    Julie King         6947
# 211   Julie King         2595
# 1697  Julie King         1595
# 1849  Julie King          653

# %%
df.loc[(df['Customer Country'] == "India") & (df['Sales POC'] == "Julie King")].sort_values(by='Order ID' , ascending=False)
# Out:
#       Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 1849   1239461          245            India 2023-09-14 01:17:00      Website
# 1697   1129422          327            India 2023-10-21 01:26:00      Website
# 211     146917          183            India 2023-02-24 01:46:00        Other
# 13       10101          276            India 2023-11-27 22:29:00          App
#
#        Sales POC  Order Value
# 1849  Julie King          653
# 1697  Julie King         1595
# 211   Julie King         2595
# 13    Julie King         6947

# %%
df.loc[(df['Customer Country'] == "India") & (df['Sales POC'] == "Julie King")].sort_values(by='Order ID' , ascending=False)[:5]
# Out:
#       Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 1849   1239461          245            India 2023-09-14 01:17:00      Website
# 1697   1129422          327            India 2023-10-21 01:26:00      Website
# 211     146917          183            India 2023-02-24 01:46:00        Other
# 13       10101          276            India 2023-11-27 22:29:00          App
#
#        Sales POC  Order Value
# 1849  Julie King          653
# 1697  Julie King         1595
# 211   Julie King         2595
# 13    Julie King         6947

# %%
df.loc[(df['Customer Country'] == "India") | (df['Sales POC'] == "Julie King")]
# Out:
#       Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 1         2011          525            India 2023-04-29 23:40:00     Whatsapp
# 12        9839          223            India 2023-06-05 01:05:00        Other
# 13       10101          276            India 2023-11-27 22:29:00          App
# 15       10508         1016            India 2023-08-24 23:13:00     Whatsapp
# 28       16847          406            India 2023-11-08 00:17:00        Other
# ...        ...          ...              ...                 ...          ...
# 2484   1675193          552            India 2023-11-12 23:47:00     Whatsapp
# 2486   1675528          360            India 2023-07-30 00:12:00     Whatsapp
# 2491   1677717          376            India 2023-06-21 23:56:00        Other
# 2496   1681214          291            India 2023-05-15 01:00:00      Website
# 2497   1681720           71            India 2023-04-06 00:24:00        Other
#
#                 Sales POC  Order Value
# 1            Paul Henriot         4551
# 12          William Brown         7215
# 13             Julie King         6947
# 15        Marta Hernandez         4247
# 28          Mart¡n Sommer         1802
# ...                   ...          ...
# 2484       Peter Ferguson         2913
# 2486           Wing C Tam         3204
# 2491       Peter Ferguson         8542
# 2496          Jan Klaeboe         8168
# 2497  Michael Donnermeyer         1552
#
# [301 rows x 7 columns]

# %%
df['Order Source'].nunique()
# Out:
# 4

# %%
top_3_sourceoditer = df['Order Source'].isin(['Website','App','Whatsapp'])

# %%
df.loc[top_3_sourceoditer]
# Out:
#       Order ID  Customer ID Customer Country      Order Datetime Order Source  \
# 1         2011          525            India 2023-04-29 23:40:00     Whatsapp
# 2         2822         1614              USA 2023-12-30 00:21:00     Whatsapp
# 3         2889          743              USA 2023-11-28 00:31:00     Whatsapp
# 4         3971           20              USA 2023-10-26 23:11:00      Website
# 5         4111         1367            Italy 2023-03-08 22:52:00          App
# ...        ...          ...              ...                 ...          ...
# 2494   1679923         1835          Finland 2023-02-23 23:59:00     Whatsapp
# 2495   1680806         1304            Italy 2023-06-23 00:29:00          App
# 2496   1681214          291            India 2023-05-15 01:00:00      Website
# 2498   1682186         1537              USA 2023-07-31 00:50:00          App
# 2499   1682358          567        Australia 2023-03-27 23:19:00      Website
#
#             Sales POC  Order Value
# 1        Paul Henriot         4551
# 2     Daniel Da Cunha         3960
# 3         Julie Young         8397
# 4         Julie Brown         5545
# 5         Juri Hirano         7800
# ...               ...          ...
# 2494     Diego Freyre         2710
# 2495   Janine Labrune         3072
# 2496      Jan Klaeboe         8168
# 2498      Steve Frick         9912
# 2499    Helen Bennett         4540
#
# [1892 rows x 7 columns]
